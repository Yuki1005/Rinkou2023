# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd
from janome.tokenizer import Tokenizer

df = pd.read_csv('titanic_train.csv')


def get_nouns(sentence, noun_list):
    for token in t.tokenize(sentence):
        split_token = token.part_of_speech.split(',')
        ## 一般名詞を抽出
        # if split_token[0] == '名詞' and split_token[1] == '一般':
        print(split_token,token.surface)
        noun_list.append(token.surface)

def depict_word_cloud(noun_list):
    ## 名詞リストの要素を空白区切りにする(word_cloudの仕様)
    noun_space = ' '.join(map(str, noun_list))
    ## word cloudの設定(フォントの設定)
    wc = WordCloud(background_color="white", font_path=r"C:/WINDOWS/Fonts/msgothic.ttc", width=300,height=300)
    wc.generate(noun_space)
    plt.figure(figsize=(5,5))
    plt.tick_params(labelbottom=False,
                    labelleft=False,
                    labelright=False,
                    labeltop=False,
                   length=0)
    ## word cloudの表示
    plt.imshow(wc)
    plt.show()
    

t = Tokenizer()

noun_list = []
for sentence in list(df['Name']):
    get_nouns(sentence, noun_list)

depict_word_cloud(noun_list)
# Out:
# ['名詞', '固有名詞', '組織', '*'] Braund
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Owen
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Harris
# ['名詞', '固有名詞', '組織', '*'] Cumings
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bradley
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Florence
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Briggs
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Thayer
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Heikkinen
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Laina
# ['名詞', '固有名詞', '組織', '*'] Futrelle
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jacques
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Heath
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Lily
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] May
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Peel
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Allen
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Henry
# ['名詞', '固有名詞', '組織', '*'] Moran
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] James
# ['名詞', '固有名詞', '組織', '*'] McCarthy
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Timothy
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] J
# ['名詞', '固有名詞', '組織', '*'] Palsson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Gosta
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Leonard
# ['名詞', '固有名詞', '組織', '*'] Johnson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Oscar
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] W
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Elisabeth
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Vilhelmina
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Berg
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Nasser
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Nicholas
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Adele
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Achem
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Sandstrom
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Marguerite
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Rut
# ['名詞', '固有名詞', '組織', '*'] Bonnell
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Elizabeth
# ['名詞', '固有名詞', '組織', '*'] Saundercock
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Henry
# ['名詞', '固有名詞', '組織', '*'] Andersson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anders
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Johan
# ['名詞', '固有名詞', '組織', '*'] Vestrom
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hulda
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Amanda
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Adolfina
# ['名詞', '固有名詞', '組織', '*'] Hewlett
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Mary
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] D
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Kingcome
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Rice
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Eugene
# ['名詞', '固有名詞', '組織', '*'] Williams
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Charles
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Eugene
# ['名詞', '固有名詞', '組織', '*'] Vander
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Planke
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Julius
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Emelia
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Maria
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Vandemoortele
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Masselmani
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Fatima
# ['名詞', '固有名詞', '組織', '*'] Fynney
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Joseph
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] J
# ['名詞', '固有名詞', '組織', '*'] Beesley
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Lawrence
# ['名詞', '固有名詞', '組織', '*'] McGowan
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anna
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '一般', '*', '*'] Annie
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '固有名詞', '組織', '*'] Sloper
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Thompson
# ['名詞', '固有名詞', '組織', '*'] Palsson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Torborg
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Danira
# ['名詞', '固有名詞', '組織', '*'] Asplund
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Carl
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Oscar
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Selma
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Augusta
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Emilia
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Johansson
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Emir
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Farred
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Chehab
# ['名詞', '固有名詞', '組織', '*'] Fortune
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Charles
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Alexander
# ['名詞', '固有名詞', '組織', '*'] O
# ['名詞', 'サ変接続', '*', '*'] '
# ['名詞', '一般', '*', '*'] Dwyer
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ellen
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '一般', '*', '*'] Nellie
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '固有名詞', '組織', '*'] Todoroff
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Lalio
# ['名詞', '固有名詞', '組織', '*'] Uruchurtu
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Don
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Manuel
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] E
# ['名詞', '固有名詞', '組織', '*'] Spencer
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Augustus
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Marie
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Eugenie
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Glynn
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mary
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Agatha
# ['名詞', '固有名詞', '組織', '*'] Wheadon
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edward
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] H
# ['名詞', '固有名詞', '組織', '*'] Meyer
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edgar
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Joseph
# ['名詞', '固有名詞', '組織', '*'] Holverson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Alexander
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Oskar
# ['名詞', '固有名詞', '組織', '*'] Mamee
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hanna
# ['名詞', '固有名詞', '組織', '*'] Cann
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ernest
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Charles
# ['名詞', '固有名詞', '組織', '*'] Vander
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Planke
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Augusta
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Maria
# ['名詞', '固有名詞', '組織', '*'] Nicola
# ['名詞', 'サ変接続', '*', '*'] -
# ['名詞', '一般', '*', '*'] Yarred
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jamila
# ['名詞', '固有名詞', '組織', '*'] Ahlin
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Johan
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Johanna
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Persdotter
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Larsson
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Turpin
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Robert
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Dorothy
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ann
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Wonnacott
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Kraeff
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Theodor
# ['名詞', '固有名詞', '組織', '*'] Laroche
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Simonne
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Marie
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anne
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Andree
# ['名詞', '固有名詞', '組織', '*'] Devaney
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Margaret
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Delia
# ['名詞', '固有名詞', '組織', '*'] Rogers
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['名詞', '固有名詞', '組織', '*'] Lennon
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Denis
# ['名詞', '固有名詞', '組織', '*'] O
# ['名詞', 'サ変接続', '*', '*'] '
# ['名詞', '一般', '*', '*'] Driscoll
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bridget
# ['名詞', '固有名詞', '組織', '*'] Samaan
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Youssef
# ['名詞', '固有名詞', '組織', '*'] Arnold
# ['名詞', 'サ変接続', '*', '*'] -
# ['名詞', '一般', '*', '*'] Franchi
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Josef
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Josefine
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Franchi
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Panula
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Juha
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Niilo
# ['名詞', '固有名詞', '組織', '*'] Nosworthy
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Richard
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Cater
# ['名詞', '固有名詞', '組織', '*'] Harper
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Henry
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Sleeper
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Myna
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Haxtun
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Faunthorpe
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Lizzie
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Elizabeth
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anne
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Wilkinson
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Ostby
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Engelhart
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Cornelius
# ['名詞', '固有名詞', '組織', '*'] Woolner
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hugh
# ['名詞', '固有名詞', '組織', '*'] Rugg
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Emily
# ['名詞', '固有名詞', '組織', '*'] Novel
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mansouer
# ['名詞', '固有名詞', '組織', '*'] West
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Constance
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mirium
# ['名詞', '固有名詞', '組織', '*'] Goodwin
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Frederick
# ['名詞', '固有名詞', '組織', '*'] Sirayanian
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Orsen
# ['名詞', '固有名詞', '組織', '*'] Icard
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Amelie
# ['名詞', '固有名詞', '組織', '*'] Harris
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Henry
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Birkhardt
# ['名詞', '固有名詞', '組織', '*'] Skoog
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Harald
# ['名詞', '固有名詞', '組織', '*'] Stewart
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Albert
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] A
# ['名詞', '固有名詞', '組織', '*'] Moubarek
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Gerios
# ['名詞', '固有名詞', '組織', '*'] Nye
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Elizabeth
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ramell
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Crease
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ernest
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] James
# ['名詞', '固有名詞', '組織', '*'] Andersson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Erna
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Alexandra
# ['名詞', '固有名詞', '組織', '*'] Kink
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Vincenz
# ['名詞', '固有名詞', '組織', '*'] Jenkin
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Stephen
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Curnow
# ['名詞', '固有名詞', '組織', '*'] Goodwin
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Lillian
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Amy
# ['名詞', '固有名詞', '組織', '*'] Hood
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ambrose
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jr
# ['名詞', '固有名詞', '組織', '*'] Chronopoulos
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Apostolos
# ['名詞', '固有名詞', '組織', '*'] Bing
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Lee
# ['名詞', '固有名詞', '組織', '*'] Moen
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Sigurd
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hansen
# ['名詞', '固有名詞', '組織', '*'] Staneff
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ivan
# ['名詞', '固有名詞', '組織', '*'] Moutal
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Rahamin
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Haim
# ['名詞', '固有名詞', '組織', '*'] Caldwell
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Alden
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Gates
# ['名詞', '固有名詞', '組織', '*'] Dowdell
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Elizabeth
# ['名詞', '固有名詞', '組織', '*'] Waelens
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Achille
# ['名詞', '固有名詞', '組織', '*'] Sheerlinck
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jan
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Baptist
# ['名詞', '固有名詞', '組織', '*'] McDermott
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Brigdet
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Delia
# ['名詞', '固有名詞', '組織', '*'] Carrau
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Francisco
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] M
# ['名詞', '固有名詞', '組織', '*'] Ilett
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bertha
# ['名詞', '固有名詞', '組織', '*'] Backstrom
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Karl
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Alfred
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Maria
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mathilda
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Gustafsson
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Ford
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Neal
# ['名詞', '固有名詞', '組織', '*'] Slocovski
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Selman
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Francis
# ['名詞', '固有名詞', '組織', '*'] Fortune
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mabel
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Helen
# ['名詞', '固有名詞', '組織', '*'] Celotti
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Francesco
# ['名詞', '固有名詞', '組織', '*'] Christmann
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Emil
# ['名詞', '固有名詞', '組織', '*'] Andreasson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Paul
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edvin
# ['名詞', '固有名詞', '組織', '*'] Chaffee
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Herbert
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Fuller
# ['名詞', '固有名詞', '組織', '*'] Dean
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bertram
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Frank
# ['名詞', '固有名詞', '組織', '*'] Coxon
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Daniel
# ['名詞', '固有名詞', '組織', '*'] Shorney
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Charles
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Joseph
# ['名詞', '固有名詞', '組織', '*'] Goldschmidt
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] George
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] B
# ['名詞', '固有名詞', '組織', '*'] Greenfield
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bertram
# ['名詞', '固有名詞', '組織', '*'] Doling
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] T
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Ada
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Julia
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bone
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Kantor
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Sinai
# ['名詞', '固有名詞', '組織', '*'] Petranec
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Matilda
# ['名詞', '固有名詞', '組織', '*'] Petroff
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Pastcho
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] ("
# ['名詞', '一般', '*', '*'] Pentcho
# ['名詞', 'サ変接続', '*', '*'] ")
# ['名詞', '固有名詞', '組織', '*'] White
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Richard
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Frasar
# ['名詞', '固有名詞', '組織', '*'] Johansson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Gustaf
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Joel
# ['名詞', '固有名詞', '組織', '*'] Gustafsson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anders
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Vilhelm
# ['名詞', '固有名詞', '組織', '*'] Mionoff
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Stoytcho
# ['名詞', '固有名詞', '組織', '*'] Salkjelsvik
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anna
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Kristine
# ['名詞', '固有名詞', '組織', '*'] Moss
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Albert
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Johan
# ['名詞', '固有名詞', '組織', '*'] Rekic
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Tido
# ['名詞', '固有名詞', '組織', '*'] Moran
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bertha
# ['名詞', '固有名詞', '組織', '*'] Porter
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Walter
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Chamberlain
# ['名詞', '固有名詞', '組織', '*'] Zabour
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hileni
# ['名詞', '固有名詞', '組織', '*'] Barton
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] David
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['名詞', '固有名詞', '組織', '*'] Jussila
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Katriina
# ['名詞', '固有名詞', '組織', '*'] Attalah
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Malake
# ['名詞', '固有名詞', '組織', '*'] Pekoniemi
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edvard
# ['名詞', '固有名詞', '組織', '*'] Connors
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Patrick
# ['名詞', '固有名詞', '組織', '*'] Turpin
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Robert
# ['名詞', '固有名詞', '組織', '*'] Baxter
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Quigg
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edmond
# ['名詞', '固有名詞', '組織', '*'] Andersson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ellis
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anna
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Maria
# ['名詞', '固有名詞', '組織', '*'] Hickman
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Stanley
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] George
# ['名詞', '固有名詞', '組織', '*'] Moore
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Leonard
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Charles
# ['名詞', '固有名詞', '組織', '*'] Nasser
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Nicholas
# ['名詞', '固有名詞', '組織', '*'] Webber
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Susan
# ['名詞', '固有名詞', '組織', '*'] White
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Percival
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Wayland
# ['名詞', '固有名詞', '組織', '*'] Nicola
# ['名詞', 'サ変接続', '*', '*'] -
# ['名詞', '一般', '*', '*'] Yarred
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Elias
# ['名詞', '固有名詞', '組織', '*'] McMahon
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Martin
# ['名詞', '固有名詞', '組織', '*'] Madsen
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Fridtjof
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Arne
# ['名詞', '固有名詞', '組織', '*'] Peter
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anna
# ['名詞', '固有名詞', '組織', '*'] Ekstrom
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Johan
# ['名詞', '固有名詞', '組織', '*'] Drazenoic
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jozef
# ['名詞', '固有名詞', '組織', '*'] Coelho
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Domingos
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Fernandeo
# ['名詞', '固有名詞', '組織', '*'] Robins
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Alexander
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] A
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Grace
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Charity
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Laury
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Weisz
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Leopold
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Mathilde
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Francoise
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Pede
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Sobey
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Samuel
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] James
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hayden
# ['名詞', '固有名詞', '組織', '*'] Richard
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Emile
# ['名詞', '固有名詞', '組織', '*'] Newsom
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Helen
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Monypeny
# ['名詞', '固有名詞', '組織', '*'] Futrelle
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jacques
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Heath
# ['名詞', '固有名詞', '組織', '*'] Osen
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Olaf
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Elon
# ['名詞', '固有名詞', '組織', '*'] Giglio
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Victor
# ['名詞', '固有名詞', '組織', '*'] Boulos
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Joseph
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '一般', '*', '*'] Sultana
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Nysten
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anna
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Sofia
# ['名詞', '固有名詞', '組織', '*'] Hakkarainen
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Pekka
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Pietari
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Elin
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Matilda
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Dolck
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Burke
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jeremiah
# ['名詞', '固有名詞', '組織', '*'] Andrew
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edgardo
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Samuel
# ['名詞', '固有名詞', '組織', '*'] Nicholls
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Joseph
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Charles
# ['名詞', '固有名詞', '組織', '*'] Andersson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] August
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edvard
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] ("
# ['名詞', '一般', '*', '*'] Wennerstrom
# ['名詞', 'サ変接続', '*', '*'] ")
# ['名詞', '固有名詞', '組織', '*'] Ford
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Robina
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Maggie
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '一般', '*', '*'] Ruby
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '固有名詞', '組織', '*'] Navratil
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Michel
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] ("
# ['名詞', '固有名詞', '組織', '*'] Louis
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] M
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hoffman
# ['名詞', 'サ変接続', '*', '*'] ")
# ['名詞', '固有名詞', '組織', '*'] Byles
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Rev
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Thomas
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Roussel
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Davids
# ['名詞', '固有名詞', '組織', '*'] Bateman
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Rev
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Robert
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] James
# ['名詞', '固有名詞', '組織', '*'] Pears
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Thomas
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Edith
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Wearne
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Meo
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Alfonzo
# ['名詞', '固有名詞', '組織', '*'] van
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Billiard
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Austin
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Blyler
# ['名詞', '固有名詞', '組織', '*'] Olsen
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ole
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Martin
# ['名詞', '固有名詞', '組織', '*'] Williams
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Charles
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Duane
# ['名詞', '固有名詞', '組織', '*'] Gilnagh
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Katherine
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '一般', '*', '*'] Katie
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '固有名詞', '組織', '*'] Corn
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Harry
# ['名詞', '固有名詞', '組織', '*'] Smiljanic
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mile
# ['名詞', '固有名詞', '組織', '*'] Sage
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Thomas
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Henry
# ['名詞', '固有名詞', '組織', '*'] Cribb
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hatfield
# ['名詞', '固有名詞', '組織', '*'] Watt
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] James
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Elizabeth
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '一般', '*', '*'] Bessie
# ['名詞', 'サ変接続', '*', '*'] "
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Inglis
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Milne
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Bengtsson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Viktor
# ['名詞', '固有名詞', '組織', '*'] Calic
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jovo
# ['名詞', '固有名詞', '組織', '*'] Panula
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Eino
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Viljami
# ['名詞', '固有名詞', '組織', '*'] Goldsmith
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Frank
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '一般', '*', '*'] Frankie
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '固有名詞', '組織', '*'] Chibnall
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Edith
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Martha
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bowerman
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Skoog
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Anna
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bernhardina
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Karlsson
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Baumann
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] D
# ['名詞', '固有名詞', '組織', '*'] Ling
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Lee
# ['名詞', '固有名詞', '組織', '*'] Van
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] der
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] hoef
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Wyckoff
# ['名詞', '固有名詞', '組織', '*'] Rice
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Arthur
# ['名詞', '固有名詞', '組織', '*'] Johnson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Eleanor
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ileen
# ['名詞', '固有名詞', '組織', '*'] Sivola
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Antti
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Wilhelm
# ['名詞', '固有名詞', '組織', '*'] Smith
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] James
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Clinch
# ['名詞', '固有名詞', '組織', '*'] Klasen
# ['名詞', 'サ変接続', '*', '*'] ,
# ...
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Albert
# ['名詞', '固有名詞', '組織', '*'] Allum
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Owen
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] George
# ['名詞', '固有名詞', '組織', '*'] Compton
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Sara
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Rebecca
# ['名詞', '固有名詞', '組織', '*'] Pasic
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jakob
# ['名詞', '固有名詞', '組織', '*'] Sirota
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Maurice
# ['名詞', '固有名詞', '組織', '*'] Chip
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Chang
# ['名詞', '固有名詞', '組織', '*'] Marechal
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Pierre
# ['名詞', '固有名詞', '組織', '*'] Alhomaki
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ilmari
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Rudolf
# ['名詞', '固有名詞', '組織', '*'] Mudd
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Thomas
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Charles
# ['名詞', '固有名詞', '組織', '*'] Serepeca
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Augusta
# ['名詞', '固有名詞', '組織', '*'] Lemberopolous
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Peter
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] L
# ['名詞', '固有名詞', '組織', '*'] Culumovic
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jeso
# ['名詞', '固有名詞', '組織', '*'] Abbing
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Anthony
# ['名詞', '固有名詞', '組織', '*'] Sage
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Douglas
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Bullen
# ['名詞', '固有名詞', '組織', '*'] Markoff
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Marin
# ['名詞', '固有名詞', '組織', '*'] Harper
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Rev
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['名詞', '固有名詞', '組織', '*'] Goldenberg
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Samuel
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] L
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Edwiga
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Grabowska
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Andersson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Sigvard
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Harald
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Elias
# ['名詞', '固有名詞', '組織', '*'] Svensson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Johan
# ['名詞', '固有名詞', '組織', '*'] Boulos
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Nourelain
# ['名詞', '固有名詞', '組織', '*'] Lines
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mary
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Conover
# ['名詞', '固有名詞', '組織', '*'] Carter
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ernest
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Courtenay
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Lilian
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hughes
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Aks
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Sam
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Leah
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Rosen
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Wick
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] George
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Dennick
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Mary
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hitchcock
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Daly
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Peter
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Denis
# ['名詞', '固有名詞', '組織', '*'] Baclini
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Solomon
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Latifa
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Qurban
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Razi
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Raihed
# ['名詞', '固有名詞', '組織', '*'] Hansen
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Claus
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Peter
# ['名詞', '固有名詞', '組織', '*'] Giles
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Frederick
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edward
# ['名詞', '固有名詞', '組織', '*'] Swift
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Frederick
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Joel
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Margaret
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Welles
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Barron
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Sage
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Dorothy
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edith
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '一般', '*', '*'] Dolly
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '固有名詞', '組織', '*'] Gill
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] John
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['名詞', '固有名詞', '組織', '*'] Bystrom
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '一般', '*', '*'] Karolina
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Duran
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] y
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] More
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Asuncion
# ['名詞', '固有名詞', '組織', '*'] Roebling
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Washington
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Augustus
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] II
# ['名詞', '固有名詞', '組織', '*'] van
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Melkebeke
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Philemon
# ['名詞', '固有名詞', '組織', '*'] Johnson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Master
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Harold
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Theodor
# ['名詞', '固有名詞', '組織', '*'] Balkic
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Cerin
# ['名詞', '固有名詞', '組織', '*'] Beckwith
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Richard
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Leonard
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Sallie
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Monypeny
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Carlsson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Frans
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Olof
# ['名詞', '固有名詞', '組織', '*'] Vander
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Cruyssen
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Victor
# ['名詞', '固有名詞', '組織', '*'] Abelson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Samuel
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Hannah
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Wizosky
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Najib
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Adele
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Kiamie
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '一般', '*', '*'] Jane
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '固有名詞', '組織', '*'] Gustafsson
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Alfred
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ossian
# ['名詞', '固有名詞', '組織', '*'] Petroff
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Nedelio
# ['名詞', '固有名詞', '組織', '*'] Laleff
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Kristo
# ['名詞', '固有名詞', '組織', '*'] Potter
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Thomas
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jr
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Lily
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Alexenia
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Wilson
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Shelley
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Imanita
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Parrish
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Hall
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Markun
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Johann
# ['名詞', '固有名詞', '組織', '*'] Dahlberg
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Gerda
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Ulrika
# ['名詞', '固有名詞', '組織', '*'] Banfield
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Frederick
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] James
# ['名詞', '固有名詞', '組織', '*'] Sutehall
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Henry
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Jr
# ['名詞', '固有名詞', '組織', '*'] Rice
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mrs
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] William
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] (
# ['名詞', '固有名詞', '組織', '*'] Margaret
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Norton
# ['名詞', 'サ変接続', '*', '*'] )
# ['名詞', '固有名詞', '組織', '*'] Montvila
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Rev
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Juozas
# ['名詞', '固有名詞', '組織', '*'] Graham
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Margaret
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Edith
# ['名詞', '固有名詞', '組織', '*'] Johnston
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Miss
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Catherine
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Helen
# ['記号', '空白', '*', '*']
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '一般', '*', '*'] Carrie
# ['名詞', 'サ変接続', '*', '*'] "
# ['名詞', '固有名詞', '組織', '*'] Behr
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Karl
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Howell
# ['名詞', '固有名詞', '組織', '*'] Dooley
# ['名詞', 'サ変接続', '*', '*'] ,
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Mr
# ['名詞', 'サ変接続', '*', '*'] .
# ['記号', '空白', '*', '*']
# ['名詞', '固有名詞', '組織', '*'] Patrick
